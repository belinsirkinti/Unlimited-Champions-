# %%
name = input("Enter your name: ")
print("Hello", name)

print("Welcome to English Tenses! Hello I am Happy the Hippo. Today we are going to learn the English tenses in a fun and easy way. Have fun!")
# Out:
# Enter your name: Belin
# Hello Belin
# Welcome to English Tenses! Hello I am Happy the Hippo. Today we are going to learn the English tenses in a fun and easy way. Have fun!

# %%
print("Let us start with the simple present.")
# Out:
# Let us start with the simple present.

# %%
bold = '\33[1m'
print("The simple present is when you use a verb to tell about things that happen continually in the present, like every day, every week, or every month. Here is an example: I \33[1mgo " + "\33[mto school every day.")
# Out:
# The simple present is when you use a verb to tell about things that happen continually in the present, like every day, every week, or every month. Here is an example: I go to school every day.

# %%
print("Now it is your turn. Write the correct verb in the \33[1msimple present" + "\33[m into the space.")
# Out:
# Now it is your turn. Write the correct verb in the simple present into the space.

# %%
a=input("Are you ready?")
if a=='Yes':
    ans=input("1. I always _____ (watch) TV in the afternoon.")
    if ans=='watch':
        print("Correct!🥳")
    else:
        print("Incorrect.Try again!")
        ans=input("1. I always _____ (watch) TV in the afternoon.")
    if ans=='watch':
        print("Yay you made it!✅")
    else:
        print("Incorrect. No worries, it will get better. The correct answer is \33[1mwatch " + "\33[m.")
# Out:
# Are you ready?Yes
# 1. I always _____ (watch) TV in the afternoon.watch
# Correct!🥳
# Yay you made it!✅

# %%
ans=input("2. I _____ (learn) English vocabulary everyday.")
if ans=='learn':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("2. I _____ (learn) English vocabulary everyday.")
if ans=='learn':
    print("Yay you made it!✅")
else:
    print("Incorrect. No worries, it will get better. The correct answer is \33[1mlearn " + "\33[m.")
# Out:
# 2. I _____ (learn) English vocabulary everyday.learn
# Correct!🥳
# Yay you made it!✅

# %%
print("You learned the simple present! Let us continue with the present progressive.")
# Out:
# You learned the simple present! Let us continue with the present progressive.

# %%
print("The present progressive is used to describe an activity currently in progress. For example: I \33[1mam reading" + "\33[m right now.")
# Out:
# The present progressive is used to describe an activity currently in progress. For example: I am reading right now.

# %%
print("Now it is your turn. Write the correct verb in the \33[1mpresent progressive" + "\33[m into the space.")
# Out:
# Now it is your turn. Write the correct verb in the present progressive into the space.

# %%
ans=input("1. Now I _____ (watch) TV.")
if ans=='am watching':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("1. Now I _____ (watch) TV.")
if ans=='am watching':
    print("Yay you made it!✅")
else:
    print("Incorrect. No worries, it will get better. The correct answer is \33[1mam watching " + "\33[m.")
# Out:
# 1. Now I _____ (watch) TV.am watching
# Correct!🥳
# Yay you made it!✅

# %%
ans=input("2. At the moment I _____ (learn) English vocabulary.")
if ans=='am learning':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("2. At the moment I _____ (learn) English vocabulary.")
if ans=='am learning':
    print("Yay you made it!✅")
else:
    print("Incorrect. No worries, it will get better. The correct answer is \33[1mam learning " + "\33[m.")
# Out:
# 2. At the moment I _____ (learn) English vocabulary.am learning
# Correct!🥳
# Yay you made it!✅

# %%
print("You learned the present progressive! Let us continue with the simple past.")
# Out:
# You learned the present progressive! Let us continue with the simple past.

# %%
print("The simple past tense of regular verbs is marked by the ending -d or -ed. An example of a simple past tense verb used in a sentence would be: I played football at the park.")
# Out:
# The simple past tense of regular verbs is marked by the ending -d or -ed. An example of a simple past tense verb used in a sentence would be: I played football at the park.

# %%
print("Now it is your turn. Write the correct verb in the \33[1msimple past" + "\33[m into the space.")
# Out:
# Now it is your turn. Write the correct verb in the simple past into the space.

# %%
ans=input("1. I _____ (watch) TV yesterday.")
if ans=='watched':
        print("Correct!😄")
else:
    print("Incorrect.Try again!")
    ans=input("1. I _____ (watch) TV yesterday.")
if ans=='watched':
    print("Yay you made it!✅")
else:
    print("Incorrect. No worries, it will get better. The correct answer is \33[1mwatched " + "\33[m.")
# Out:
# 1. I _____ (watch) TV yesterday.watched
# Correct!😄
# Yay you made it!✅

# %%
ans=input("2. I _____ (learn) English vocabulary a week ago.")
if ans=='learned':
        print("Correct!😄")
else:
    print("Incorrect.Try again!")
    ans=input("2. I _____ (learn) English vocabulary a week ago.")
if ans=='learned':
    print("Yay you made it!✅")
else:
    print("Incorrect. No worries, it will get better. The correct answer is \33[1mlearned " + "\33[m.")
# Out:
# 2. I _____ (learn) English vocabulary a week ago.learned
# Correct!😄
# Yay you made it!✅

# %%
print("You learned the simple past! Let us continue with the past progressive.")
# Out:
# You learned the simple past! Let us continue with the past progressive.

# %%
print("The past progressive tense refers to a continuing action or state that was happening at some point in the past. The past progressive tense is formed by combining the past tense of to be (i.e., was/were) with the verb's present participle (-ing word). For example: The sun was shining everyday that summer.")
# Out:
# The past progressive tense refers to a continuing action or state that was happening at some point in the past. The past progressive tense is formed by combining the past tense of to be (i.e., was/were) with the verb's present participle (-ing word). For example: The sun was shining everyday that summer.

# %%
print("Now it is your turn. Write the correct verb in the past progressive into the space.")
# Out:
# Now it is your turn. Write the correct verb in the past progressive into the space.

# %%
ans=input("1. I _____ (watch) TV.")
if ans=='was watching':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("1. I _____ (watch) TV.")
if ans=='was watching':
    print("Yay you made it!✅")
else:
    print("Incorrect. No worries, it will get better. The correct answeris \33[1mwas watching " + "\33[m.")
# Out:
# 1. I _____ (watch) TV.was watching
# Correct!🥳
# Yay you made it!✅

# %%
ans=input("2. While I _____ (learn) English vocabulary, my mom was cooking dinner.")
if ans=='was learning':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("2. While I _____ (learn) English vocabulary, my mom was cooking dinner.")
if ans=='was learning':
    print("Yay you made it!✅")
else:
    print("Incorrect. No worries, it will get better. The correct answer is \33[1mwas learning " + "\33[m.")
# Out:
# 2. While I _____ (learn) English vocabulary, my mom was cooking dinner.was learning
# Correct!🥳
# Yay you made it!✅

# %%
print("You learned the past progressive! Let us continue with the future.")
# Out:
# You learned the past progressive! Let us continue with the future.

# %%
print("The will-future tense is a tense used for a future activity or a future state of being. To build the will-future you use will + infinitive. For example: The weather \33[1mwill be" + "\33[m nice tomorrow.")
# Out:
# The will-future tense is a tense used for a future activity or a future state of being. To build the will-future you use will + infinitive. For example: The weather will be nice tomorrow.

# %%
print("Now it is your turn. Write the correct verb in the \33[1mwill-future" + "\33[m into the space.")
# Out:
# Now it is your turn. Write the correct verb in the will-future into the space.

# %%
ans=input("1. I think the sun _____ (shine) tomorrow.")
if ans=='will shine':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("1. I think the sun _____ (shine) tomorrow.")
if ans=='will shine':
    print("Yay you made it!✅")
else:
    print("Incorrect. No worries, it will get better. The correct answer is \33[1mwill shine " + "\33[m.")
# Out:
# 1. I think the sun _____ (shine) tomorrow.will shine
# Correct!🥳
# Yay you made it!✅

# %%
ans=input("2. I hope our teacher _____ (not give) us homework today.")
if ans=='will not give':
        print("Correct!🥳")
else:
    print("Incorrect.Try again!")
    ans=input("2. I hope our teacher _____ (not give) us homework today.")
if ans=='will not give':
    print("Yay you made it!✅")
else:
    print("Incorrect. No worries, it will get better. The correct answer is\33[1mwill not give " + "\33[m.")
# Out:
# 2. I hope our teacher _____ (not give) us homework today.will not give
# Correct!🥳
# Yay you made it!✅
